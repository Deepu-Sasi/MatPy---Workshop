# %%
import matplotlib.pyplot as mp
import pandas as pd
import seaborn as sb

data=pd.read_csv("C:/Users/user/Downloads/advertising.csv")

print(data.corr())
dataplot=sb.heatmap(data.corr(), cmap="crest", annot=True)

mp.show()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
import matplotlib.pyplot as mp
import pandas as pd
import numpy as np
# %matplotlib inline
advert=pd.read_csv("C:/Users/user/Downloads/advertising.csv")
#view firt five entries
advert.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
advert.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
advert.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
import seaborn as sns
#relation between features and responses
sns.pairplot(advert, x_vars=['TV','Radio','Newspaper'],y_vars='Sales',height=10, aspect=0.7,kind='reg')
advert.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
X=advert[['TV']]
X.head()
y=advert.Sales

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X, y, random_state=1)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (150, 1)
# (150,)
# (50, 1)
# (50,)

# %%
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(linreg.coef_)
print(linreg.intercept_)
# Out:
# [0.05565473]
# 6.902718095764663

# %%
#LOGISTIC REGRESSION

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn import datasets
from sklearn.inspection import DecisionBoundaryDisplay

#import some data to play with
iris=datasets.load_iris()
X=iris.data[:,:2]                 #we only take the first two features.
Y=iris.target

#create an instance of logistic regression classifier and fit the data
logreg=LogisticRegression(C=1)
logreg.fit(X,Y)

_,ax=plt.subplots(figsize=(4,3))
DecisionBoundaryDisplay.from_estimator(
    logreg,
    X,
    cmap=plt.cm.Paired, 
    ax=ax,
    response_method="predict",
    plot_method="pcolormesh",
    shading="auto",
    xlabel="sepal length",
    ylabel="sepal width",
    eps=0.5,

)

#plot also the training points

plt.scatter(X[:,0],X[:,1], c=Y, edgecolors="k", cmap=plt.cm.Paired)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
# !pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\new  one\newone\lib\site-packages (1.0.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.2-cp39-cp39-win_amd64.whl (7.4 MB)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\user\anaconda3\new  one\newone\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\user\anaconda3\new  one\newone\lib\site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\user\anaconda3\new  one\newone\lib\site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\new  one\newone\lib\site-packages (from scikit-learn) (2.2.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# Successfully installed scikit-learn-1.1.2
